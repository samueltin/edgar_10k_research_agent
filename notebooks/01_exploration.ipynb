# %% [markdown]
# # Exploration notebook
# Scratch space for testing EDGAR calls and iterating on prompts before promoting code into `src/`.

# %%
import sys
sys.path.insert(0, '../src')

from edgar_research_agent.edgar_client.xbrl_facts import get_income_statement

df, name, cik = get_income_statement('MSFT')
df.head()
